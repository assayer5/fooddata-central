# %%
# data from FoodData Central: https://fdc.nal.usda.gov/
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
# read subset of branded food csv
branded = pd.read_csv('./data_csvs/branded_food.csv', 
                      usecols=['fdc_id', 'brand_owner', 'brand_name', 'ingredients', 'branded_food_category'])

print('dataframe shape:', branded.shape)
branded.head()
# Out:
# dataframe shape: (1947155, 5)
#     fdc_id                               brand_owner brand_name  \
# 0  1105904  Richardson Oilseed Products (US) Limited        NaN
# 1  1105905                     CAMPBELL SOUP COMPANY        NaN
# 2  1105906                     CAMPBELL SOUP COMPANY        NaN
# 3  1105907                     CAMPBELL SOUP COMPANY        NaN
# 4  1105908                     CAMPBELL SOUP COMPANY        NaN
#
#                                          ingredients  branded_food_category
# 0                                      Vegetable Oil            Oils Edible
# 1  INGREDIENTS: BEEF STOCK, CONTAINS LESS THAN 2%...  Herbs/Spices/Extracts
# 2  INGREDIENTS: CLAM STOCK, POTATOES, CLAMS, CREA...         Prepared Soups
# 3  INGREDIENTS: WATER, CREAM, BROCCOLI, CELERY, V...         Prepared Soups
# 4  INGREDIENTS: CHICKEN STOCK, CONTAINS LESS THAN...  Herbs/Spices/Extracts

# %%
# read subset of food csv
food = pd.read_csv('./data_csvs/food.csv', usecols=['fdc_id', 'description'])
print('dataframe shape:', food.shape)
food.head()
# Out:
# dataframe shape: (1947155, 2)
#     fdc_id                                  description
# 0  1105904                   WESSON Vegetable Oil 1 GAL
# 1  1105905                           SWANSON BROTH BEEF
# 2  1105906     CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER
# 3  1105907  CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI
# 4  1105908                        SWANSON BROTH CHICKEN

# %%
# join food and branded dataframes
branded_food = branded.join(food.set_index('fdc_id'), on='fdc_id', how='left')
print('dataframe shape:', branded_food.shape)
branded_food.head()
# Out:
# dataframe shape: (1947155, 6)
#     fdc_id                               brand_owner brand_name  \
# 0  1105904  Richardson Oilseed Products (US) Limited        NaN
# 1  1105905                     CAMPBELL SOUP COMPANY        NaN
# 2  1105906                     CAMPBELL SOUP COMPANY        NaN
# 3  1105907                     CAMPBELL SOUP COMPANY        NaN
# 4  1105908                     CAMPBELL SOUP COMPANY        NaN
#
#                                          ingredients  branded_food_category  \
# 0                                      Vegetable Oil            Oils Edible
# 1  INGREDIENTS: BEEF STOCK, CONTAINS LESS THAN 2%...  Herbs/Spices/Extracts
# 2  INGREDIENTS: CLAM STOCK, POTATOES, CLAMS, CREA...         Prepared Soups
# 3  INGREDIENTS: WATER, CREAM, BROCCOLI, CELERY, V...         Prepared Soups
# 4  INGREDIENTS: CHICKEN STOCK, CONTAINS LESS THAN...  Herbs/Spices/Extracts
#
#                                    description
# 0                   WESSON Vegetable Oil 1 GAL
# 1                           SWANSON BROTH BEEF
# 2     CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER
# 3  CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI
# 4                        SWANSON BROTH CHICKEN

# %%
# clean up the column entries
# strip whitespace
for col in ['brand_owner', 'brand_name', 'description']:
    branded_food[col] = branded_food[col].str.strip()
    
# upper case column entries
for col in ['brand_owner', 'brand_name']:
    branded_food[col] = branded_food[col].str.upper()
    
# lower case column entries, clean up text
branded_food['ingredients'] = branded_food['ingredients'].str.lower()
branded_food['ingredients'] = branded_food['ingredients'].str.replace('ingredients:','').str.strip()

branded_food.head()
# Out:
#     fdc_id                               brand_owner brand_name  \
# 0  1105904  RICHARDSON OILSEED PRODUCTS (US) LIMITED        NaN
# 1  1105905                     CAMPBELL SOUP COMPANY        NaN
# 2  1105906                     CAMPBELL SOUP COMPANY        NaN
# 3  1105907                     CAMPBELL SOUP COMPANY        NaN
# 4  1105908                     CAMPBELL SOUP COMPANY        NaN
#
#                                          ingredients  branded_food_category  \
# 0                                      vegetable oil            Oils Edible
# 1  beef stock, contains less than 2% of: mirepoix...  Herbs/Spices/Extracts
# 2  clam stock, potatoes, clams, cream, vegetable ...         Prepared Soups
# 3  water, cream, broccoli, celery, vegetable oil ...         Prepared Soups
# 4  chicken stock, contains less than 2% of: yeast...  Herbs/Spices/Extracts
#
#                                    description
# 0                   WESSON Vegetable Oil 1 GAL
# 1                           SWANSON BROTH BEEF
# 2     CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER
# 3  CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI
# 4                        SWANSON BROTH CHICKEN

# %%
# recategorize some food items that were miscategorized in original database entry

# bool indicating if row 'branded food category' is vegetable category
cond = [True if 'vegetable' in str(branded_food.at[idx, 'branded_food_category']).lower() else False 
        for idx in branded_food.index]
# get indexes of vegetable based categories
vegprod_idx = branded_food[cond].index

# iterate though descriptions to recategorize
for idx in vegprod_idx:
    # get description, covert to lower case
    fooddescript = str(branded_food.at[idx, 'description']).lower()
    # check for words that indicate different category
    if any(wrd in fooddescript for wrd in ['burger', 'patties', 'patty']):
        category = 'Meat Substitutes'
    elif 'pizza' in fooddescript:
        category = 'Pizza'
    elif any(wrd in fooddescript for wrd in ['diced', 'crushed']):
        category = 'Canned Vegetables'
    elif any(wrd in fooddescript for wrd in ['paste', 'pesto', 'puree', ' sauce']):
        category = 'sauces, condiments'
    elif 'snack' in fooddescript:
        category = 'Other Snacks'
    else:
        continue
        
    # fill in catgory    
    branded_food.at[idx, 'branded_food_category'] = category

# indexes of 'processed cereal products' branded food category
cond = branded_food['branded_food_category'] == 'Processed Cereal Products'
cerealprod_idx = branded_food[cond].index

# iterate though descriptions to recategorize
for idx in cerealprod_idx:
    # get description, covert to lower case
    fooddescript = str(branded_food.at[idx, 'description']).lower()
    # check for words that indicate different category
    if ' bar' in fooddescript:
        category = 'Cereal/Muesli Bars'
    else:
        continue
        
    # fill in catgory    
    branded_food.at[idx, 'branded_food_category'] = category

    
# rows with branded food category filled (not nan)
bfc_notnanidx = branded_food[branded_food['branded_food_category'].notna()].index

# iterate though descriptions to recategorize
for idx in bfc_notnanidx:
    # get description, covert to lower case
    fooddescript = str(branded_food.at[idx, 'description']).lower()
    
    if 'cadbury' in fooddescript:
        category = 'candy'
    elif "kellogg's all-in-one bowls/pouches" in fooddescript:
        category = 'cereal'
    elif 'yakult' in fooddescript:
        category = 'Yogurt'
    elif 'rimming salt' in fooddescript:
        category = 'sauces, condiments'
    else:
        continue
        
    # fill in catgory    
    branded_food.at[idx, 'branded_food_category'] = category

# %%
# check number of nans in joined dataframes
branded_food.isna().sum()
# Out:
# fdc_id                        0
# brand_owner               16890
# brand_name               547847
# ingredients                5393
# branded_food_category     10608
# description                   1
# dtype: int64

# %%
# rows with nan in branded food category
bfc_nanidx = branded_food[branded_food['branded_food_category'].isna()].index

# %%
# check rows with nan for branded food category
branded_food.loc[bfc_nanidx, :][50:80]
# show more characters in description
# with pd.option_context("display.max_colwidth", 100):
#     print(branded_food.loc[bfc_nanidx,'description'][50:80])
# Out:
#        fdc_id brand_owner brand_name  \
# 33985  345569     CARGILL        NaN
# 33986  345570     CARGILL        NaN
# 34101  345685    RED GOLD        NaN
# 34102  345686    RED GOLD        NaN
# 34103  345687    RED GOLD        NaN
# 34104  345688    RED GOLD        NaN
# 34105  345689    RED GOLD        NaN
# 34106  345690    RED GOLD        NaN
# 34107  345691    RED GOLD        NaN
# 34108  345692    RED GOLD        NaN
# 34109  345693    RED GOLD        NaN
# 34110  345694    RED GOLD        NaN
# 34111  345695    RED GOLD        NaN
# 34285  345869    RED GOLD        NaN
# 34286  345870    RED GOLD        NaN
# 34287  345871    RED GOLD        NaN
# 34288  345872    RED GOLD        NaN
# 34289  345873    RED GOLD        NaN
# 34290  345874    RED GOLD        NaN
# 34291  345875    RED GOLD        NaN
# 34292  345876    RED GOLD        NaN
# 34293  345877    RED GOLD        NaN
# 34294  345878    RED GOLD        NaN
# 34295  345879    RED GOLD        NaN
# 34296  345880    RED GOLD        NaN
# 34297  345881    RED GOLD        NaN
# 34298  345882    RED GOLD        NaN
# 34299  345883    RED GOLD        NaN
# 34300  345884    RED GOLD        NaN
# 34301  345885    RED GOLD        NaN
#
#                                              ingredients  \
# 33985                         turkey, natural flavoring.
# 33986                   turkey breast, natural flavoring
# 34101                      tomato paste and citric acid.
# 34102  tomatoes with juice, water, chopped green chil...
# 34103  tomatoes with juice, water, chopped green chil...
# 34104  tomato concentrate, high fructose corn syrup, ...
# 34105  tomato concentrate, high fructose corn syrup, ...
# 34106  tomato concentrate, sugar, distilled vinegar, ...
# 34107  organic tomato concentrate (water, organic tom...
# 34108  tomato concentrate from red ripe tomatoes, tap...
# 34109  tomato concentrate, high fructose corn syrup ,...
# 34110  tomato concentrate, high fructose corn syrup, ...
# 34111  tomato concentrate, high fructose corn syrup, ...
# 34285  tomato concentrate, high fructose corn syrup, ...
# 34286  tomato puree (water, tomato paste), high fruct...
# 34287  tomato concentrate (water, tomato paste), high...
# 34288  tomato concentrate (water, tomato paste), dice...
# 34289  tomato concentrate (water, tomato paste), dice...
# 34290  tomatoes, water, tomato paste, corn, green chi...
# 34291  tomato puree (water, tomato paste), high fruct...
# 34292  red gold® ketchup (tomato concentrate from red...
# 34293  tomatoes with juice, water, chiles, sugar, sal...
# 34294  tomato puree (water, tomato paste), diced toma...
# 34295  tomatoes, tomato juice, less than 2% of: salt,...
# 34296  tomatoes, tomato puree, salt, basil, citric ac...
# 34297  tomato puree (water, tomato paste), citric aci...
# 34298  tomatoes, tomato juice, contains less than 2% ...
# 34299  tomatoes, tomato juice, less than 2% of: calci...
# 34300  tomatoes, tomato juice, less than 2% of: salt,...
# 34301  tomatoes, tomato juice, less than 2% of: calci...
#
#       branded_food_category                                        description
# 33985                   NaN               Honeysuckle White 93/7 Ground Turkey
# 33986                   NaN         Honeysuckle White 99% Ground Turkey Breast
# 34101                   NaN                         Red Gold 6oz. Tomato Paste
# 34102                   NaN  Red Gold 10oz Diced Tomatoes w/ Green Chilies ...
# 34103                   NaN  Red Gold 10oz Petite Diced Tomatoes w/ Green C...
# 34104                   NaN                              Red Gold 14oz Ketchup
# 34105                   NaN           Red Gold 20oz Ketchup Upside Down Bottle
# 34106                   NaN      Red Gold 20oz. Tomato Ketchup with Real Sugar
# 34107                   NaN                Red Gold 20oz. Organic Ketchup USDB
# 34108                   NaN        Red Gold 19.5oz. Naturally Balanced Ketchup
# 34109                   NaN     Red Gold 20oz Colts Ketchup Upside Down Bottle
# 34110                   NaN      Red Gold Mama Selita's 20z Ketchup w/Jalapeno
# 34111                   NaN                              Red Gold 32oz Ketchup
# 34285                   NaN                              Red Gold 64oz Ketchup
# 34286                   NaN                         Red Gold 12oz. Chili Sauce
# 34287                   NaN                       Red Gold 12oz. Seafood Sauce
# 34288                   NaN                        Red Gold 15.5oz. Mild Salsa
# 34289                   NaN                      Red Gold 15.5oz. Medium Salsa
# 34290                   NaN    Red Gold 15.5oz Salsa Black Beans & Corn SQ Jar
# 34291                   NaN                    Red Gold 15oz. Sloppy Joe Sauce
# 34292                   NaN          Huy Fong 20z Ketchup Style Sriracha Sauce
# 34293                   NaN  Huy Fong 10oz. Sriracha Diced Tomatoes & Red C...
# 34294                   NaN             Huy Fong 15.5oz. Sriracha Medium Salsa
# 34295                   NaN  Tuttorosso Blue 35oz. Whole Peeled Tomatoes w/...
# 34296                   NaN    Tuttorosso Blue 35oz. Crushed Tomatoes w/ Basil
# 34297                   NaN         Tuttorosso Blue 35oz. 1.045 Puree w/ Basil
# 34298                   NaN  Tuttorosso Green 28oz. Whole Peeled Plum Tomat...
# 34299                   NaN  Tuttorosso Green 28oz. NSA Whole Peeled Plum T...
# 34300                   NaN     Tuttorosso Green 28oz. Diced Tomatoes in Juice
# 34301                   NaN          Tuttorosso Green 28oz. NSA Diced Tomatoes

# %%
# define key words to search for in food description, use key words to fill nans in branded food category
candywords = ['candy', 'cadbury', 'chocolate bar']

snackwords = [' bar', 'bite', 'chips', 'crisps', ' cracker', 'dorito', 'granola', 'grahams', 'gummie', "lay's",
              'popcorn', 'pretzel', 'puff', 'seeds', 'slim jim', 'snack', 'skins', 'square', 'trail mix'] # not 'bar mix'
notsnackwords = ['bar mix', 'barq', 'cookie dough', 'popcorn chicken', 'boyardee', 'soup'] # , 'chocolate bar'

drinkwords = ['beverage', 'bottle', 'cola ', 'coke', 'drink', 'juice', 'punch', 'soda', 'sparkling', 'tea ', 'quencher']

cerealwords = ['cereal', 'instant oat'] # not 'cereal bar'

prepwords = ['bowl', 'burrito', 'chili', 'chowder', 'dinner', 'dumpling', 'fried', 'lasagna', 'linguini', ' meal', 
             'microwave', 'nugget', 'pizza', 'plate', 'pot pie', 'potsticker', 'ravioli', 'rigatoni', 'skillet', 
             'steamer', 'soup', 'tenders','toaster', 'tortellini']

saucewords = ['broth', 'dressing', 'gravy', 'paste', 'sauce', 'salsa', 'spread', 'topping', 'ketchup'] # 'peanut butter'

meatwords = ['beef', 'bologna', 'crab', 'fillet', 'flounder', 'frank', 'legs', 'link', 'loin', 
             'patty', 'pattie', 'pork', 'portion', 'ribeye', 'salami', 'sausage', 'turkey', 'tuna'] # , 'chicken'
            # brand owner 'beaver street fisheries'
    
vegwords = ['beans', 'berries', 'crushed', 'diced', 'peas', 'peeled']

dairywords = ['yogurt']

dessertwords = ['pie', 'cobbler']

# %%
# %%time
# fill branded food category nans 
for idx in bfc_nanidx:
    # get description, covert to lower case
    fooddescript = str(branded_food.at[idx, 'description']).lower()
    
    # check food description for words that would likely categorize them
    # category - candy
    if any(wrd in fooddescript for wrd in candywords):
        category = 'candy'
    # category - snack foods
    elif any(wrd in fooddescript for wrd in snackwords) and all(wrd not in fooddescript for wrd in notsnackwords):
        category = 'snacks'
    # category - cereal
    elif any(wrd in fooddescript for wrd in cerealwords) and 'cereal bar' not in fooddescript:
        category = 'cereal'
    # category - prepared foods
    elif any(wrd in fooddescript for wrd in prepwords) and 'chilie' not in fooddescript:
        category = 'prepared food/meals'
    # category - sauces and condiments
    elif any(wrd in fooddescript for wrd in saucewords):
        category = 'sauces, condiments'
    # category - drinks
    elif any(wrd in fooddescript for wrd in drinkwords) and all(wrd not in fooddescript for wrd in vegwords):
        category = 'drinks'
    # category - meat, poultry, seafood
    elif 'beaver street fisheries' in str(branded_food.at[idx, 'brand_owner']).lower() or \
    any(wrd in fooddescript for wrd in meatwords):
        category = 'meat, poultry, seafood'
    # category - dairy
    elif any(wrd in fooddescript for wrd in dairywords):
        category = 'dairy'
    # category - vegetables and fruits
    elif any(wrd in fooddescript for wrd in vegwords):
        category = 'veg, fruit'
    # category - desserts
    elif any(wrd in fooddescript for wrd in dessertwords):
        category = 'dessert'
    # otherwise leave nan
    else:
        category = np.nan
        
    # fill in catgory    
    branded_food.at[idx, 'branded_food_category'] = category
# Out:
# CPU times: total: 1.39 s
# Wall time: 1.79 s

# %%
# check nans of joined dataframes
branded_food.isna().sum()
# Out:
# fdc_id                        0
# brand_owner               16890
# brand_name               547847
# ingredients                5393
# branded_food_category      2846
# description                   1
# dtype: int64

# %%
# check filled values of branded food category
branded_food.loc[bfc_nanidx,:][150:180]
# Out:
#        fdc_id     brand_owner brand_name  \
# 34444  346028  CONAGRA BRANDS        NaN
# 34445  346029  CONAGRA BRANDS        NaN
# 34446  346030  CONAGRA BRANDS        NaN
# 34447  346031  CONAGRA BRANDS        NaN
# 34448  346032  CONAGRA BRANDS        NaN
# 34449  346033  CONAGRA BRANDS        NaN
# 34450  346034  CONAGRA BRANDS        NaN
# 34451  346035  CONAGRA BRANDS        NaN
# 34452  346036  CONAGRA BRANDS        NaN
# 34453  346037  CONAGRA BRANDS        NaN
# 34454  346038  CONAGRA BRANDS        NaN
# 34455  346039  CONAGRA BRANDS        NaN
# 34456  346040  CONAGRA BRANDS        NaN
# 34457  346041  CONAGRA BRANDS        NaN
# 34458  346042  CONAGRA BRANDS        NaN
# 34459  346043  CONAGRA BRANDS        NaN
# 34460  346044  CONAGRA BRANDS        NaN
# 34461  346045  CONAGRA BRANDS        NaN
# 34462  346046  CONAGRA BRANDS        NaN
# 34463  346047  CONAGRA BRANDS        NaN
# 34464  346048  CONAGRA BRANDS        NaN
# 34465  346049  CONAGRA BRANDS        NaN
# 34466  346050  CONAGRA BRANDS        NaN
# 34469  346053  CONAGRA BRANDS        NaN
# 34470  346054  CONAGRA BRANDS        NaN
# 34473  346057  CONAGRA BRANDS        NaN
# 34483  346067  CONAGRA BRANDS        NaN
# 34484  346068  CONAGRA BRANDS        NaN
# 34485  346069  CONAGRA BRANDS        NaN
# 34486  346070  CONAGRA BRANDS        NaN
#
#                                              ingredients  \
# 34444  tomato puree (water, tomato paste), less than ...
# 34445                          tomato paste, citric acid
# 34446  tomato puree (water, tomato paste), water, les...
# 34447  tomato puree (water, tomato paste), water, les...
# 34448  vine-ripened tomatoes, tomato juice, less than...
# 34449  tomato puree (water, tomato paste), water, les...
# 34450  tomato puree (water, tomato paste), water, les...
# 34451  tomato puree (water, tomato paste), water, les...
# 34452  tomato puree (water, tomato paste), tomatoes, ...
# 34453  tomato puree (water, tomato paste), tomatoes, ...
# 34454  tomato puree (water, tomato paste), diced toma...
# 34455  tomato puree (water, tomato paste), water, dis...
# 34456  strawberries, corn syrup, sugar, high fructose...
# 34457  tomatoes in juice (tomatoes, tomato juice, cal...
# 34458  blueberries, sugar, water, corn syrup, modifie...
# 34459  red raspberries, sugar, water, corn syrup, mod...
# 34460  assorted chicken pieces (breast with back port...
# 34461  soybean oil, water, buttermilk, palm kernel oi...
# 34462  cherries, sugar, corn syrup, water, modified c...
# 34463  high fructose corn syrup, water, corn syrup, s...
# 34464  bag: whole grain popping corn, palm oil, less ...
# 34465  cooked beef, beef, onions, salt, onion powder,...
# 34466  cooked beef, beef, salt, water, chili powder, ...
# 34469                             sunflower seeds, salt.
# 34470                             sunflower seeds, salt.
# 34473                               pumpkin seeds, salt.
# 34483  tomatoes, tomato juice, less than 2% of: sugar...
# 34484  tomatoes, tomato juice, less than 2% of: salt,...
# 34485  unpeeled diced tomatoes, tomato juice, less th...
# 34486  diced tomatoes, tomato juice, less than 2% of:...
#
#         branded_food_category  \
# 34444                     NaN
# 34445      sauces, condiments
# 34446      sauces, condiments
# 34447      sauces, condiments
# 34448              veg, fruit
# 34449      sauces, condiments
# 34450      sauces, condiments
# 34451      sauces, condiments
# 34452      sauces, condiments
# 34453      sauces, condiments
# 34454     prepared food/meals
# 34455      sauces, condiments
# 34456      sauces, condiments
# 34457     prepared food/meals
# 34458      sauces, condiments
# 34459      sauces, condiments
# 34460     prepared food/meals
# 34461     prepared food/meals
# 34462      sauces, condiments
# 34463                     NaN
# 34464                     NaN
# 34465  meat, poultry, seafood
# 34466     prepared food/meals
# 34469                  snacks
# 34470                  snacks
# 34473                  snacks
# 34483              veg, fruit
# 34484              veg, fruit
# 34485              veg, fruit
# 34486              veg, fruit
#
#                                              description
# 34444                  Hunt's Tomato Puree, 29 oz, 29 OZ
# 34445                          HUNTS Tomato Paste, 29 OZ
# 34446             HUNTS No Salt Added Tomato Sauce, 8 OZ
# 34447                          HUNTS Tomato Sauce, 15 OZ
# 34448  ANGELA MIA Petite Diced Tomatoes, #10 Can, 6/1...
# 34449     HUNTS Tomato Sauce, #10 Can, 6/105 oz., 105 OZ
# 34450  Hunt's Tomato Sauce with Basil, Garlic, and Or...
# 34451                           HUNTS Tomato Sauce, 8 OZ
# 34452  ANGELA MIA No Salt Added Spaghetti Sauce, Pouc...
# 34453  ANGELA MIA Marinara Sauce, #10 Can, 6/104 oz.,...
# 34454  HUNTS Tomato Sauce For Original Mild Chili Sta...
# 34455  HUNTS Tomato Sauce For Meatloaf Starter, 15.25 OZ
# 34456  Sliced Strawberry Topping, Wide-Mouth Jugs, 11...
# 34457  HUNTS Tomato Sauce For Medium Chili Starter, 1...
# 34458         Blueberry Topping, Wide-Mouth Jugs, 122 OZ
# 34459         Raspberry Topping, Wide-Mouth Jugs, 122 OZ
# 34460   BANQUET Original Fried Chicken Jumbo Pack, 42 OZ
# 34461   FLEISCHMANNS Olive Oil Soft Spread Bowl, 11.9 OZ
# 34462          Cherry Topping, Wide-Mouth Jugs, 123.4 OZ
# 34463   Fiesta Strawberry Puree, Wide-Mouth Jugs, 118 OZ
# 34464              ORVILLE 2-Step White Cheddar, 3.24 OZ
# 34465               LIBBYS Corned Beef With Onion, 12 OZ
# 34466               LIBBYS Corned Beef With Chili, 12 OZ
# 34469            DAVID Original Sunflower Seeds, 1.75 OZ
# 34470            DAVID Original Sunflower Seeds, 5.25 OZ
# 34473                          DAVID Pumpkin Seeds, 5 OZ
# 34483  HUNTS Diced Basil Grarlic Oregano Tomatoes Var...
# 34484         HUNTS Diced Tomatoes Petite Variety, 13 OZ
# 34485                  HUNTS Fire Roasted Diced Tomatoes
# 34486               HUNTS Petite Diced Tomatoes, 14.5 OZ

# %%
branded_food['branded_food_category'].value_counts()
# Out:
# branded_food_category
# Popcorn, Peanuts, Seeds & Related Snacks                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           92023
# Candy                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              88445
# Cheese                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             81306
# Ice Cream & Frozen Yogurt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          60720
# Cookies & Biscuits                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 53501
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# Eggs Products/Substitutes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Skin Care Preparations                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# Includes any products that can be described/observed as a prepared food normally consumed as the last course of a meal. These products have been packaged in such a way as to extend their consumable life. Products include desserts that are biscuit based, bread based, cake/sponge based, dairy based, pastry based and rice based. Excludes products such as Perishable and Frozen Desserts, Ice Cream, Pastries and Cakes, Yogurt.                                                                                                                                                                                                                               1
# Ready-made combination meal, frozen dinner, frozen meal, or microwave meal is a pre-packaged frozen full meal.  The meal requires no preparation other than cooking and contains all the elements typically contained in a single-serving meal.  A ready-made meal (also known as a TV Dinner) must have a main component and at least one additional component such as a side item, a dessert and/or beverage. These products require cooking prior to consumption. These products must be frozen to extend their consumable life.                                                                                                                                    1
# Includes any products that can be described/observed as frozen food made from the curd of milk, separated from the whey, sometimes fermented, and usually pressed, cooked, smoked, matured, or heated and mixed with artificial ingredients, such as emulsifiers, colourings and flavourings. These products must be frozen to extend their consumable life. These products include natural, processed cheese, cheese with added ingredients, such as herbs and nuts, in blocks, rolls, slices, grated, cubes, spreadable and portions. Excludes products such as Shelf Stable and Perishable Cheeses, all Cheese Substitutes and Cheese-Based/Flavoured Meals.        1
# Name: count, Length: 437, dtype: int64

# %%
# condense 'branded food category' values of interest into a smaller number of more general categories
# load csv with 'branded food category' values condensed into 7 overall categories
catdf = pd.read_csv('./category-sorting-files/FoodData Project - Branded Food Categories.csv')
catdf.head()
# Out:
#   MEAT, POULTRY, SEAFOOD, MEAT SUBSTITUTES      FRUITS, VEGETABLES, LEGUMES  \
# 0                    Frozen Fish & Seafood  Pre-Packaged Fruit & Vegetables
# 1                              Other Meats                Frozen Vegetables
# 2                           Canned Seafood                Canned Vegetables
# 3                           Fish & Seafood                     Canned Fruit
# 4                              Canned Tuna           Canned & Bottled Beans
#
#   EGGS, DAIRY, DAIRY SUBSTITUTES  \
# 0                         Cheese
# 1                           Milk
# 2               Plant Based Milk
# 3      Ice Cream & Frozen Yogurt
# 4      Cheese/Cheese Substitutes
#
#                                 DRINKS (NON-DAIRY)  \
# 0  Fruit & Vegetable Juice, Nectars & Fruit Drinks
# 1                                            Water
# 2                                     Other Drinks
# 3                                             Soda
# 4                                Iced & Bottle Tea
#
#                                            CEREAL  \
# 0                                          Cereal
# 1                       Processed Cereal Products
# 2  Cereals Products - Ready to Eat (Shelf Stable)
# 3                Breakfast Cereals - Hot And Cold
# 4     Cereal Products - Ready to Eat (Perishable)
#
#                                      SNACKS  \
# 0  Popcorn, Peanuts, Seeds & Related Snacks
# 1                 Chips, Pretzels & Snacks,
# 2              Snack, Energy & Granola Bars
# 3                              Other Snacks
# 4                          Wholesome Snacks
#
#                  PREPARED FOODS/MEALS
# 0            Frozen Dinners & Entrees
# 1  Frozen Appetizers & Hors D'oeuvres
# 2                               Pizza
# 3                         Other Soups
# 4                         Canned Soup

# %%
# create new 'category' column with foods recategorized into the new categories
# iterate through each column, column label will be new category value
for category in catdf.columns:
    # iterate through 'branded food category' values in each column
    for bfc in catdf[category]:
        # create mask for branded food category with value bfc
        mask = branded_food['branded_food_category'] == bfc
        # fill category column with new category
        branded_food.loc[mask, 'category'] = category
        
branded_food.head()
# Out:
#     fdc_id                               brand_owner brand_name  \
# 0  1105904  RICHARDSON OILSEED PRODUCTS (US) LIMITED        NaN
# 1  1105905                     CAMPBELL SOUP COMPANY        NaN
# 2  1105906                     CAMPBELL SOUP COMPANY        NaN
# 3  1105907                     CAMPBELL SOUP COMPANY        NaN
# 4  1105908                     CAMPBELL SOUP COMPANY        NaN
#
#                                          ingredients  branded_food_category  \
# 0                                      vegetable oil            Oils Edible
# 1  beef stock, contains less than 2% of: mirepoix...  Herbs/Spices/Extracts
# 2  clam stock, potatoes, clams, cream, vegetable ...         Prepared Soups
# 3  water, cream, broccoli, celery, vegetable oil ...         Prepared Soups
# 4  chicken stock, contains less than 2% of: yeast...  Herbs/Spices/Extracts
#
#                                    description              category
# 0                   WESSON Vegetable Oil 1 GAL                   NaN
# 1                           SWANSON BROTH BEEF                   NaN
# 2     CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER  PREPARED FOODS/MEALS
# 3  CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI  PREPARED FOODS/MEALS
# 4                        SWANSON BROTH CHICKEN                   NaN

# %%
# drop food categories that are not of interest (ie. candy, sauces, baking mix...)
branded_food.dropna(axis=0, subset='category', inplace=True)

print('branded food shape', branded_food.shape)
branded_food.head()
# Out:
# branded food shape (1202625, 7)
#     fdc_id            brand_owner brand_name  \
# 2  1105906  CAMPBELL SOUP COMPANY        NaN
# 3  1105907  CAMPBELL SOUP COMPANY        NaN
# 5  1105909  CAMPBELL SOUP COMPANY        NaN
# 8  1105912  CAMPBELL SOUP COMPANY        NaN
# 9  1105913  CAMPBELL SOUP COMPANY        NaN
#
#                                          ingredients  \
# 2  clam stock, potatoes, clams, cream, vegetable ...
# 3  water, cream, broccoli, celery, vegetable oil ...
# 5  water, pea beans, carrots, cooked ham - water ...
# 8  tomato puree (water, tomato paste), water, hig...
# 9  water, tomato puree (water, tomato paste), chi...
#
#           branded_food_category                                  description  \
# 2                Prepared Soups     CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER
# 3                Prepared Soups  CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI
# 5                Prepared Soups                 CAMPBELL'S SOUP BEAN AND HAM
# 8                Prepared Soups                       CAMPBELL'S SOUP TOMATO
# 9  Dough Based Products / Meals        CAMPBELL'S PASTA SPAGHETTIOS W FRANKS
#
#                category
# 2  PREPARED FOODS/MEALS
# 3  PREPARED FOODS/MEALS
# 5  PREPARED FOODS/MEALS
# 8  PREPARED FOODS/MEALS
# 9  PREPARED FOODS/MEALS

# %%
branded_food['category'].value_counts()
# Out:
# category
# SNACKS                                      330989
# EGGS, DAIRY, DAIRY SUBSTITUTES              224513
# PREPARED FOODS/MEALS                        178116
# DRINKS (NON-DAIRY)                          161215
# MEAT, POULTRY, SEAFOOD, MEAT SUBSTITUTES    140145
# FRUITS, VEGETABLES, LEGUMES                 125490
# CEREAL                                       42157
# Name: count, dtype: int64

# %%
descriptcount = branded_food['description'].value_counts()
descriptcount[descriptcount > 1][:10]
# Out:
# description
# ICE CREAM              2451
# 2% REDUCED FAT MILK    1909
# CUT GREEN BEANS        1517
# SODA                   1309
# PREMIUM ICE CREAM      1192
# FAT FREE MILK          1167
# PINTO BEANS            1135
# WHOLE MILK             1086
# 1% LOWFAT MILK          999
# DICED TOMATOES          993
# Name: count, dtype: int64

# %%
# create subcategories
# load csv with some 'branded food category' values put into subcategories
subcatdf = pd.read_csv('./category-sorting-files/FoodData Project - Branded Food SubCategories.csv')
subcatdf.head()
# Out:
#                             SEAFOOD  \
# 0             Frozen Fish & Seafood
# 1                    Canned Seafood
# 2                    Fish & Seafood
# 3                       Canned Tuna
# 4  Shellfish Unprepared/Unprocessed
#
#                                    UNPROCESSED MEATS  \
# 0                          Poultry, Chicken & Turkey
# 1                   Frozen Poultry, Chicken & Turkey
# 2                          Frozen Chicken - Portions
# 3                    Turkey - Unprepared/Unprocessed
# 4  Meat/Poultry/Other Animals  Unprepared/Unproce...
#
#                                    PROCESSED MEATS  \
# 0                     Chicken - Prepared/Processed
# 1                       Frozen Chicken - Processed
# 2                      Turkey - Prepared/Processed
# 3                        Fresh Chicken - Processed
# 4  Meat/Poultry/Other Animals – Prepared/Processed
#
#   PREPARED FRUITS, VEGETABLES  \
# 0           Frozen Vegetables
# 1           Canned Vegetables
# 2                Canned Fruit
# 3      Canned & Bottled Beans
# 4                    Tomatoes
#
#                        UNPREPARED FRUITS, VEGETABLES  \
# 0        Vegetables  Unprepared/Unprocessed (Frozen)
# 1      Fruits  Unprepared/Unprocessed (Shelf Stable)
# 2            Fruits  Unprepared/Unprocessed (Frozen)
# 3       Vegetables – Unprepared/Unprocessed (Frozen)
# 4  Vegetables – Unprepared/Unprocessed (Shelf Sta...
#
#                                 CHEESE  \
# 0                               Cheese
# 1            Cheese/Cheese Substitutes
# 2                 Cheese - Speciality
# 3                       Cheese - Block
# 4  Processed Cheese & Cheese Novelties
#
#                                 ICE CREAM                       MILK  \
# 0               Ice Cream & Frozen Yogurt                       Milk
# 1  Ice Cream/Ice Novelties (Shelf Stable)           Plant Based Milk
# 2                     Ice-Cream Take Home      Milk/Milk Substitutes
# 3                  Ice-Cream/Block Single  Milk/Cream - Shelf Stable
# 4          Ice-Cream/Ice-Block Multi Pack    Cream/Cream Substitutes
#
#                                    YOGURT                              EGGS  \
# 0                                  Yogurt            Eggs & Egg Substitutes
# 1               Yogurt/Yogurt Substitutes             Eggs/Eggs Substitutes
# 2                     Yogurt (Perishable)                              Eggs
# 3                    Dairy Foods/Yoghurts         Eggs Products/Substitutes
# 4  Yogurt/Yogurt Substitutes (Perishable)  Dairy/Egg Based Products / Meals
#
#    ...                               NUTS, SEEDS  \
# 0  ...  Popcorn, Peanuts, Seeds & Related Snacks
# 1  ...              Fruit/Nuts/Seeds Combination
# 2  ...                    Popcorn (Shelf Stable)
# 3  ...                        Snack Foods - Nuts
# 4  ...            Nuts/Seeds  Prepared/Processed
#
#                  COOKIES, CRACKERS  \
# 0               Cookies & Biscuits
# 1          Flavored Snack Crackers
# 2              Crackers & Biscotti
# 3                 Biscuits/Cookies
# 4  Biscuits/Cookies (Shelf Stable)
#
#                                      CHIPS, MUNCHIES  \
# 0                          Chips, Pretzels & Snacks,
# 1                                       Other Snacks
# 2                                   Wholesome Snacks
# 3                                Snack Foods - Chips
# 4  Chips/Crisps/Snack Mixes - Natural/Extruded (S...
#
#                                              PIZZA  \
# 0                                            Pizza
# 1  Pies/Pastries/Pizzas/Quiches - Savoury (Frozen)
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#                         SOUP, STEW                                    DELI  \
# 0                      Other Soups                             Deli Salads
# 1                      Canned Soup              Prepared Subs & Sandwiches
# 2                   Prepared Soups             Prepared Wraps and Burittos
# 3  Soups - Prepared (Shelf Stable)           Sandwiches/Filled Rolls/Wraps
# 4                     Chili & Stew  Sandwiches/Filled Rolls/Wraps (Frozen)
#
#                                          BREAKFAST  \
# 0    Frozen Breakfast Sandwiches, Biscuits & Meals
# 1  Frozen Pancakes, Waffles, French Toast & Crepes
# 2           Breakfast Sandwiches, Biscuits & Meals
# 3                                  Breakfast Foods
# 4         Pancakes, Waffles, French Toast & Crepes
#
#                                               DINNER  \
# 0                           Frozen Dinners & Entrees
# 1                                      Pasta Dinners
# 2                    Pizza Mixes & Other Dry Dinners
# 3                                     Prepared Meals
# 4  Vegetable Based Products / Meals - Not Ready t...
#
#                             APPETIZER  \
# 0  Frozen Appetizers & Hors D'oeuvres
# 1                        Frozen Meals
# 2                        Frozen Foods
# 3                                 NaN
# 4                                 NaN
#
#                                                SIDES
# 0                       Grain Based Products / Meals
# 1  Grain Based Products / Meals - Not Ready to Ea...
# 2                              Frozen Prepared Sides
# 3                               Flavored Rice Dishes
# 4  Vegetable Based Products / Meals - Not Ready t...
#
# [5 rows x 28 columns]

# %%
# create 'subcategory' column, partially fill using 'branded food category'
# iterate through each column of subcategory dataframe, column label will be new subcategory value
for subcategory in subcatdf.columns:
    # iterate through 'branded food category' values in each column
    for bfc in subcatdf[subcategory]:
        # create mask for branded food category with value bfc
        mask = branded_food['branded_food_category'] == bfc
        # fill subcategory column with new subcategory
        branded_food.loc[mask, 'subcategory'] = subcategory

# %%
# check subcategory nan values
branded_food[branded_food['subcategory'].isna()] # [200:250]
# Out:
#           fdc_id       brand_owner    brand_name  \
# 50       1105954  WELCH FOODS INC.           NaN
# 51       1105955  WELCH FOODS INC.           NaN
# 52       1105956  WELCH FOODS INC.           NaN
# 53       1105957  WELCH FOODS INC.           NaN
# 54       1105958  WELCH FOODS INC.           NaN
# ...          ...               ...           ...
# 1947077  2662191     TARGET STORES  ARCHER FARMS
# 1947078  2662192     TARGET STORES  ARCHER FARMS
# 1947079  2662193     TARGET STORES  ARCHER FARMS
# 1947141  2662255     TARGET STORES  ARCHER FARMS
# 1947142  2662256     TARGET STORES  ARCHER FARMS
#
#                                                ingredients  \
# 50       orange juice from concentrate (filtered water,...
# 51       filtered water, high fructose corn syrup, appl...
# 52       filtered water, high fructose corn syrup, cran...
# 53       orange juice from concentrate (filtered water,...
# 54       filtered water, high fructose corn syrup, cran...
# ...                                                    ...
# 1947077             water, sugar, coffee, natural flavors.
# 1947078                              water, sugar, coffee.
# 1947079         water, coffee, natural flavors, sucralose.
# 1947141  maple crunch granola (whole grain rolled oats,...
# 1947142  pumpkin spice granola (whole grain rolled oats...
#
#                            branded_food_category  \
# 50       Non Alcoholic Beverages  Ready to Drink
# 51       Non Alcoholic Beverages  Ready to Drink
# 52       Non Alcoholic Beverages  Ready to Drink
# 53       Non Alcoholic Beverages  Ready to Drink
# 54       Non Alcoholic Beverages  Ready to Drink
# ...                                          ...
# 1947077                             Other Drinks
# 1947078                             Other Drinks
# 1947079                             Other Drinks
# 1947141                                   Cereal
# 1947142                                   Cereal
#
#                                                description  \
# 50                            10 FL OZ 100% JUICE - ORANGE
# 51                      16 FL OZ JUICE DRINK - FRUIT PUNCH
# 52                11.5 FL OZ JUICE DRINK - APPLE CRANBERRY
# 53                           5.5 FL OZ 100% JUICE - ORANGE
# 54                    5.5 FL OZ JUICE COCKTAIL - CRANBERRY
# ...                                                    ...
# 1947077  CARAMEL MACCHIATO COFFEE CONCENTRATE, CARAMEL ...
# 1947078          DONUT SHOP COFFEE CONCENTRATE, DONUT SHOP
# 1947079  CARAMEL MACCHIATO SUGAR FREE COFFEE CONCENTRAT...
# 1947141                 MAPLE CRUNCH GRANOLA, MAPLE CRUNCH
# 1947142               PUMPKIN SPICE GRANOLA, PUMPKIN SPICE
#
#                    category subcategory
# 50       DRINKS (NON-DAIRY)         NaN
# 51       DRINKS (NON-DAIRY)         NaN
# 52       DRINKS (NON-DAIRY)         NaN
# 53       DRINKS (NON-DAIRY)         NaN
# 54       DRINKS (NON-DAIRY)         NaN
# ...                     ...         ...
# 1947077  DRINKS (NON-DAIRY)         NaN
# 1947078  DRINKS (NON-DAIRY)         NaN
# 1947079  DRINKS (NON-DAIRY)         NaN
# 1947141              CEREAL         NaN
# 1947142              CEREAL         NaN
#
# [140616 rows x 8 columns]

# %%
# indexes where subcategory is nan
subcat_nanidx = branded_food[branded_food['subcategory'].isna()].index

# %%
# define key words to search for in food description, use key words to fill nans in subcategory
juicewords = ['juice', 'v8']

sodawords = ['bottle', 'cola ', 'coke', 'soda']

teacofwords = ['tea', 'kombucha', 'coffee', 'latte']

sportwords = ['gatorade', 'quencher']

waterwords = ['sparkling']

barwords = [' bar']

oatwords = [' oat', 'oatmeal']

soupwords = ['soup', 'campbell']

# %%
# %%time
# fill subcategory for items not well categorized by the branded food category
# fill subcategory nans 
for idx in subcat_nanidx:
    # get description, covert to lower case
    fooddescript = str(branded_food.at[idx, 'description']).lower()
    foodcat = branded_food.at[idx, 'category']
    
    # check food description for words that would likely categorize them
    # category - drinks
    if foodcat == 'DRINKS (NON-DAIRY)':
        if any(wrd in fooddescript for wrd in juicewords):
            subcategory = 'JUICE'
        elif any(wrd in fooddescript for wrd in sodawords):
            subcategory = 'SODA'
        elif any(wrd in fooddescript for wrd in teacofwords):
            subcategory = 'TEA, COFFEE'
        elif any(wrd in fooddescript for wrd in sportwords):
            subcategory = 'SPORT, ENERGY DRINKS'
        elif any(wrd in fooddescript for wrd in waterwords):
            subcategory = 'WATER'
        else: 
            subcategory = 'OTHER'
            
    # category - snack foods
    elif foodcat == 'SNACKS':
        if any(wrd in fooddescript for wrd in barwords):
            subcategory = 'SNACK BARS'
        else: 
            subcategory = 'OTHER'
            
    # category - prepared foods
    elif foodcat == 'PREPARED FOODS/MEALS':
        if any(wrd in fooddescript for wrd in soupwords):
            subcategory = 'SOUP, STEW'
        else: 
            subcategory = 'OTHER'
            
    # category - cereal
    elif foodcat == 'CEREAL':
        if any(wrd in fooddescript for wrd in oatwords):
            subcategory = 'OATMEAL'
        elif 'granola' in fooddescript:
            subcategory = 'GRANOLA'
        else: 
            subcategory = 'OTHER'
    # otherwise leave nan
    else:
        subcategory = np.nan
        
    # fill in subcatgory    
    branded_food.at[idx, 'subcategory'] = subcategory
# Out:
# CPU times: total: 22.7 s
# Wall time: 27.7 s

# %%
branded_food.head()
# Out:
#     fdc_id            brand_owner brand_name  \
# 2  1105906  CAMPBELL SOUP COMPANY        NaN
# 3  1105907  CAMPBELL SOUP COMPANY        NaN
# 5  1105909  CAMPBELL SOUP COMPANY        NaN
# 8  1105912  CAMPBELL SOUP COMPANY        NaN
# 9  1105913  CAMPBELL SOUP COMPANY        NaN
#
#                                          ingredients  \
# 2  clam stock, potatoes, clams, cream, vegetable ...
# 3  water, cream, broccoli, celery, vegetable oil ...
# 5  water, pea beans, carrots, cooked ham - water ...
# 8  tomato puree (water, tomato paste), water, hig...
# 9  water, tomato puree (water, tomato paste), chi...
#
#           branded_food_category                                  description  \
# 2                Prepared Soups     CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER
# 3                Prepared Soups  CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI
# 5                Prepared Soups                 CAMPBELL'S SOUP BEAN AND HAM
# 8                Prepared Soups                       CAMPBELL'S SOUP TOMATO
# 9  Dough Based Products / Meals        CAMPBELL'S PASTA SPAGHETTIOS W FRANKS
#
#                category subcategory
# 2  PREPARED FOODS/MEALS  SOUP, STEW
# 3  PREPARED FOODS/MEALS  SOUP, STEW
# 5  PREPARED FOODS/MEALS  SOUP, STEW
# 8  PREPARED FOODS/MEALS  SOUP, STEW
# 9  PREPARED FOODS/MEALS      DINNER

# %%
# need to check nutrition values of duplicate food products once dataframes combined
branded_food.to_csv('cleaned_branded_food.csv', index=False)
